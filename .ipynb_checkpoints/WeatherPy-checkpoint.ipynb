# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
# from citipy import citipy
import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
# lat_range = (-90, 90)
# lng_range = (-180, 180)

lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
cities_nf = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

# lats = np.random.uniform(lat_range[0], lat_range[1], size=100)
# lngs = np.random.uniform(lng_range[0], lng_range[1], size=100)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
total_cities = len(cities)
print(total_cities)
cities
# Out:
# 633
# ['halalo',
#  'qaanaaq',
#  'port alfred',
#  'taolanaro',
#  'attawapiskat',
#  'itaqui',
#  'huntsville',
#  'jamestown',
#  'illoqqortoormiut',
#  'mataura',
#  'vaini',
#  'cape town',
#  'tasiilaq',
#  'castro',
#  'mehamn',
#  'ixtapa',
#  'kapaa',
#  'provideniya',
#  'butaritari',
#  'lambari',
#  'tiksi',
#  'saskylakh',
#  'dikson',
#  'nanortalik',
#  'ushuaia',
#  'hithadhoo',
#  'arraial do cabo',
#  'punta arenas',
#  'vestmannaeyjar',
#  'rapid valley',
#  'avarua',
#  'barentsburg',
#  'antakya',
#  'busselton',
#  'manzhouli',
#  'sabalgarh',
#  'bluff',
#  'bredasdorp',
#  'hobart',
#  'nykoping',
#  'sawakin',
#  'saldanha',
#  'krasnoselkup',
#  'severo-kurilsk',
#  'rikitea',
#  'egvekinot',
#  'ruatoria',
#  'khatanga',
#  'adrar',
#  'yellowknife',
#  'carnarvon',
#  'taltal',
#  'fortuna',
#  'san rafael',
#  'catuday',
#  'meulaboh',
#  'neiafu',
#  'nagua',
#  'siparia',
#  'manokwari',
#  'port lincoln',
#  'farah',
#  'aklavik',
#  'leningradskiy',
#  'chokurdakh',
#  'carmarthen',
#  'bengkulu',
#  'puerto ayora',
#  'dabakala',
#  'puerto pinasco',
#  'port elizabeth',
#  'fort wellington',
#  'karamea',
#  'zhuhai',
#  'mar del plata',
#  'bandarbeyla',
#  'hermanus',
#  'kayerkan',
#  'itarema',
#  'denpasar',
#  'atuona',
#  'prince rupert',
#  'coxquihui',
#  'mareeba',
#  'guatire',
#  'tevaitoa',
#  'tuatapere',
#  'maxixe',
#  'sept-iles',
#  'louisbourg',
#  'rosario',
#  'cockburn harbour',
#  'raudeberg',
#  'kodiak',
#  'awjilah',
#  'barrow',
#  'hasaki',
#  'saleaula',
#  'olinda',
#  'port hardy',
#  'avera',
#  'clyde river',
#  'geraldton',
#  'nemuro',
#  'klaksvik',
#  'nouadhibou',
#  'maceio',
#  'albany',
#  'tatarsk',
#  'touros',
#  'ilhabela',
#  'paradwip',
#  'ust-omchug',
#  'am timan',
#  'isangel',
#  'bahia blanca',
#  'umm lajj',
#  'chernyshevskiy',
#  'bambous virieux',
#  'longyearbyen',
#  'hualmay',
#  'ugra',
#  'bethel',
#  'georgetown',
#  'sao filipe',
#  'ola',
#  'vardo',
#  'cabo san lucas',
#  'new norfolk',
#  'narsaq',
#  'gaziantep',
#  'nikolskoye',
#  'guane',
#  'bathsheba',
#  'chapais',
#  'cidreira',
#  'ponta do sol',
#  'kalabo',
#  'cap-aux-meules',
#  'hamilton',
#  'satitoa',
#  'gornopravdinsk',
#  'road town',
#  'pandan',
#  'bandar-e lengeh',
#  'kawalu',
#  'abu zabad',
#  'walvis bay',
#  'flinders',
#  'maldonado',
#  'severnyy',
#  'upernavik',
#  'bima',
#  'lolua',
#  'margate',
#  'ust-uda',
#  'cayambe',
#  'ribeira grande',
#  'kysyl-syr',
#  'inongo',
#  'abha',
#  'tumannyy',
#  'blagoyevo',
#  'sentyabrskiy',
#  'sitka',
#  'aykhal',
#  'lebu',
#  'vangaindrano',
#  'luderitz',
#  'bargal',
#  'urengoy',
#  'komsomolskiy',
#  'tuktoyaktuk',
#  'muros',
#  'laguna',
#  'katangli',
#  'sturgeon falls',
#  'hailar',
#  'sola',
#  'sorvag',
#  'wenatchee',
#  'athens',
#  'kaitangata',
#  'east london',
#  'mys shmidta',
#  'belushya guba',
#  'weligama',
#  'kavaratti',
#  'hervey bay',
#  'vryheid',
#  'shimoda',
#  'santa isabel do rio negro',
#  'katiola',
#  'rovaniemi',
#  'hilo',
#  'morristown',
#  'husavik',
#  'talnakh',
#  'kruisfontein',
#  'amderma',
#  'saint-augustin',
#  'leh',
#  'raga',
#  'erdenet',
#  'muroto',
#  'lompoc',
#  'royan',
#  'pudozh',
#  'khandyga',
#  'pevek',
#  'marevo',
#  'daru',
#  'edd',
#  'tessalit',
#  'saint-philippe',
#  'pisco',
#  'thompson',
#  'faanui',
#  'umzimvubu',
#  'san felipe',
#  'kuche',
#  'karratha',
#  'tautira',
#  'katsuura',
#  'huimanguillo',
#  'zhitikara',
#  'alofi',
#  'palmer',
#  'harper',
#  'chikoy',
#  'nizhneyansk',
#  'mahebourg',
#  'caravelas',
#  'chapleau',
#  'lata',
#  'banda aceh',
#  'alugan',
#  'guerrero negro',
#  'naron',
#  'dunedin',
#  'key west',
#  'kozhevnikovo',
#  'ruwi',
#  'bidduang',
#  'janow lubelski',
#  'frontera',
#  'chuy',
#  'grand river south east',
#  'jalu',
#  'victoria',
#  'belaya gora',
#  'trebisacce',
#  'taoudenni',
#  'gualaquiza',
#  'kjollefjord',
#  'samusu',
#  'yanan',
#  'nuuk',
#  'beringovskiy',
#  'iralaya',
#  'wewak',
#  'monopoli',
#  'nabire',
#  'rawannawi',
#  'dunyapur',
#  'mogadishu',
#  'verkhnyaya inta',
#  'taburi',
#  'zhigansk',
#  'arman',
#  'cedar city',
#  'paracuru',
#  'frontignan',
#  'helong',
#  'iglesias',
#  'morondava',
#  'san rafael del sur',
#  'vila velha',
#  'avila',
#  'vaitupu',
#  'esperance',
#  'correia pinto',
#  'fuchu',
#  'ilulissat',
#  'longonjo',
#  'iranshahr',
#  'one hundred mile house',
#  'gorontalo',
#  'cleethorpes',
#  'saint george',
#  'kudahuvadhoo',
#  'turukhansk',
#  'amga',
#  'sibolga',
#  'comrie',
#  'kampong thum',
#  'yangambi',
#  'cherdyn',
#  'kenai',
#  'prince george',
#  'norman wells',
#  'elizabeth city',
#  'abu samrah',
#  'shelburne',
#  'oranjemund',
#  'broome',
#  'jumla',
#  'sur',
#  'mount isa',
#  'harbour breton',
#  'taboao da serra',
#  'russell',
#  'lorengau',
#  'lensk',
#  'mumford',
#  'puerto leguizamo',
#  'helena',
#  'nome',
#  'goderich',
#  'tigil',
#  'saint anthony',
#  'fort nelson',
#  'cherskiy',
#  'jabinyanah',
#  'portland',
#  'ewa beach',
#  'santa rosa',
#  'bahir dar',
#  'oum hadjer',
#  'poum',
#  'eureka',
#  'zabol',
#  'sisimiut',
#  'strezhevoy',
#  'henties bay',
#  'aquiraz',
#  'inhambane',
#  'torbay',
#  'diamantino',
#  'sindor',
#  'khonuu',
#  'telenesti',
#  'melun',
#  'mangan',
#  'karatuzskoye',
#  'kodinsk',
#  'sioux lookout',
#  'quatre cocos',
#  'bintulu',
#  'tashtagol',
#  'salalah',
#  'lugovoy',
#  'lagoa',
#  'sobolevo',
#  'loandjili',
#  'cayenne',
#  'ust-barguzin',
#  'long',
#  'sangar',
#  'kungurtug',
#  'iqaluit',
#  'freeport',
#  'barcelos',
#  'verkh-usugli',
#  'wuwei',
#  'batangafo',
#  'mega',
#  'slave lake',
#  'codrington',
#  'alihe',
#  'mayor pablo lagerenza',
#  'navolato',
#  'haines junction',
#  'souillac',
#  'brigantine',
#  'kuryk',
#  'bay roberts',
#  'tsihombe',
#  'namibe',
#  'dubbo',
#  'chara',
#  'salekhard',
#  'general pico',
#  'natal',
#  'bubaque',
#  'muisne',
#  'abaza',
#  'lelydorp',
#  'trelew',
#  'paola',
#  'necochea',
#  'george',
#  'vyazemskiy',
#  'timizart',
#  'marrakesh',
#  'redmond',
#  'niksar',
#  'kazalinsk',
#  'hofn',
#  'urucara',
#  'lisakovsk',
#  'wana',
#  'laguna de perlas',
#  'sterling',
#  'hingorja',
#  'sierpc',
#  'utiroa',
#  'praya',
#  'port-gentil',
#  'maba',
#  'ambilobe',
#  'sjovegan',
#  'kota belud',
#  'san roque',
#  'roros',
#  'chipinge',
#  'umm bab',
#  'praia da vitoria',
#  'maki',
#  'isabela',
#  'taber',
#  'saint-pierre',
#  'cap malheureux',
#  'phek',
#  'marawi',
#  'civitavecchia',
#  'masvingo',
#  'cambrils',
#  'batagay',
#  'gizo',
#  'katsiveli',
#  'marsaxlokk',
#  'oron',
#  'marcona',
#  'kahului',
#  'rock sound',
#  'galiwinku',
#  'camacha',
#  'sao joao da barra',
#  'campo maior',
#  'mayo',
#  'ust-nera',
#  'chitral',
#  'yermish',
#  'morant bay',
#  'mangrol',
#  'takoradi',
#  'kanigiri',
#  'dubuque',
#  'san andres',
#  'conakry',
#  'tura',
#  'skali',
#  'vanimo',
#  'borovskoy',
#  'ambon',
#  'san ramon',
#  'los llanos de aridane',
#  'clonakilty',
#  'high level',
#  'general roca',
#  'barcelona',
#  'fairbanks',
#  'santa fe',
#  'kovdor',
#  'broken hill',
#  'chenzhou',
#  'kattivakkam',
#  'zelenoborskiy',
#  'diffa',
#  'garissa',
#  'kulhudhuffushi',
#  'sa kaeo',
#  'umm kaddadah',
#  'kolondieba',
#  'shakhtinsk',
#  'yzeure',
#  'eyl',
#  'eugene',
#  'boende',
#  'sao francisco de paula',
#  'algiers',
#  'cabra',
#  'darhan',
#  'balashov',
#  'dolinsk',
#  'zachagansk',
#  'suntar',
#  'grand gaube',
#  'dudinka',
#  'lamu',
#  'kavieng',
#  'mansa',
#  'hambantota',
#  'northam',
#  'dingle',
#  'chicama',
#  'lazaro cardenas',
#  'honningsvag',
#  'poronaysk',
#  'mason city',
#  'the valley',
#  'pacific grove',
#  'tari',
#  'salta',
#  'waingapu',
#  'sataua',
#  'gimli',
#  'bowen',
#  'gelemso',
#  'kijang',
#  'xiongshi',
#  'kazachinskoye',
#  'srednekolymsk',
#  'bethanien',
#  'burica',
#  'atar',
#  'coquimbo',
#  'norrkoping',
#  'perth',
#  'bousso',
#  'venado tuerto',
#  'paamiut',
#  'doka',
#  'cristalina',
#  'cabedelo',
#  'kanchanaburi',
#  'el faiyum',
#  'santander jimenez',
#  'valentin gomez farias',
#  'zlitan',
#  'dombarovskiy',
#  'kirkwall',
#  'safwah',
#  'rungata',
#  'constitucion',
#  'cozumel',
#  'liwan',
#  'tateyama',
#  'emerald',
#  'juneau',
#  'vila franca do campo',
#  'porto walter',
#  'pasto',
#  'killam',
#  'ouadda',
#  'korla',
#  'baruun-urt',
#  'hamadan',
#  'viet tri',
#  'ankang',
#  'ponta delgada',
#  'moberly',
#  'ketchikan',
#  'trairi',
#  'merrill',
#  'opuwo',
#  'airai',
#  'paragominas',
#  'kuva',
#  'vostok',
#  'ajdabiya',
#  'naile',
#  'xuanzhou',
#  'yarmouth',
#  'dumas',
#  'uige',
#  'katastarion',
#  'gold coast',
#  'ahipara',
#  'chase',
#  'fairview',
#  'las cruces',
#  'merida',
#  'bonfim',
#  'farafangana',
#  'moose factory',
#  'zonguldak',
#  'takapau',
#  'mnogovershinnyy',
#  'san quintin',
#  'mandera',
#  'belmonte',
#  'riyadh',
#  'bolshaya sosnova',
#  'jibuti',
#  'betioky',
#  'dryden',
#  'tabou',
#  'calama',
#  'novichikha',
#  'takhtamygda',
#  'genhe',
#  'alenquer',
#  'aquidauana',
#  'hanzhong',
#  'tarakan',
#  'patrocinio',
#  'le port',
#  'chagda',
#  'severnyy-kospashskiy',
#  'alsonemedi',
#  'casablanca',
#  'el angel',
#  'grand-lahou',
#  'nioro',
#  'bolungarvik',
#  'westport',
#  'nogent-sur-oise',
#  'makueni',
#  'cheuskiny',
#  'rognan',
#  'artyk',
#  'ferrol',
#  'shitanjing',
#  'aflu',
#  'russkaya polyana',
#  'florence',
#  'smithers',
#  'saint-francois',
#  'talaya',
#  'kaeo',
#  'sagua de tanamo',
#  'merauke',
#  'fairlie',
#  'grand centre',
#  'nyurba',
#  'santa luzia',
#  'yar-sale',
#  'peniche',
#  'emba',
#  'tiverton',
#  'hammerfest']

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
# city = "weiser"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
# cities = ["Paris", "London", "Oslo", "Beijing"]
# response = requests.get(query_url + city).json()

# print(json.dumps(response, indent = 4))
# print(response['coord']['lat'])
# print(response['main']['temp'])
# print(response['main']['temp_max'])
# print(response['main']['humidity'])
# print(response['clouds']['all'])
# print(response['wind']['speed'])
# print(response['sys']['country'])
# print(response['dt'])


# # set up lists to hold reponse info
lat = []
lng = []
temp = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
count = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("---------------------------")
# Loop through the list of cities and perform a request for data on each
for city in cities:
    print(f"Processing Record {count} of {total_cities} | {city}")
    count +=1
    response = requests.get(query_url + city).json()
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
    except KeyError:
        print("City not found. Skipping...")
        cities_nf.append(city)
#     temp.append(response['main']['temp'])

# print(cities_nf)

new_cities = list(set(cities) - set(cities_nf))

weather_dict = {
    "City": new_cities,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date    
}
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of 633 | halalo
# City not found. Skipping...
# Processing Record 2 of 633 | qaanaaq
# Processing Record 3 of 633 | port alfred
# Processing Record 4 of 633 | taolanaro
# City not found. Skipping...
# Processing Record 5 of 633 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of 633 | itaqui
# Processing Record 7 of 633 | huntsville
# Processing Record 8 of 633 | jamestown
# Processing Record 9 of 633 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of 633 | mataura
# Processing Record 11 of 633 | vaini
# Processing Record 12 of 633 | cape town
# Processing Record 13 of 633 | tasiilaq
# Processing Record 14 of 633 | castro
# Processing Record 15 of 633 | mehamn
# Processing Record 16 of 633 | ixtapa
# Processing Record 17 of 633 | kapaa
# Processing Record 18 of 633 | provideniya
# Processing Record 19 of 633 | butaritari
# Processing Record 20 of 633 | lambari
# Processing Record 21 of 633 | tiksi
# Processing Record 22 of 633 | saskylakh
# Processing Record 23 of 633 | dikson
# Processing Record 24 of 633 | nanortalik
# Processing Record 25 of 633 | ushuaia
# Processing Record 26 of 633 | hithadhoo
# Processing Record 27 of 633 | arraial do cabo
# Processing Record 28 of 633 | punta arenas
# Processing Record 29 of 633 | vestmannaeyjar
# Processing Record 30 of 633 | rapid valley
# Processing Record 31 of 633 | avarua
# Processing Record 32 of 633 | barentsburg
# City not found. Skipping...
# Processing Record 33 of 633 | antakya
# Processing Record 34 of 633 | busselton
# Processing Record 35 of 633 | manzhouli
# Processing Record 36 of 633 | sabalgarh
# Processing Record 37 of 633 | bluff
# Processing Record 38 of 633 | bredasdorp
# Processing Record 39 of 633 | hobart
# Processing Record 40 of 633 | nykoping
# Processing Record 41 of 633 | sawakin
# Processing Record 42 of 633 | saldanha
# Processing Record 43 of 633 | krasnoselkup
# Processing Record 44 of 633 | severo-kurilsk
# Processing Record 45 of 633 | rikitea
# Processing Record 46 of 633 | egvekinot
# Processing Record 47 of 633 | ruatoria
# City not found. Skipping...
# Processing Record 48 of 633 | khatanga
# Processing Record 49 of 633 | adrar
# Processing Record 50 of 633 | yellowknife
# Processing Record 51 of 633 | carnarvon
# Processing Record 52 of 633 | taltal
# Processing Record 53 of 633 | fortuna
# Processing Record 54 of 633 | san rafael
# Processing Record 55 of 633 | catuday
# Processing Record 56 of 633 | meulaboh
# Processing Record 57 of 633 | neiafu
# Processing Record 58 of 633 | nagua
# Processing Record 59 of 633 | siparia
# Processing Record 60 of 633 | manokwari
# Processing Record 61 of 633 | port lincoln
# Processing Record 62 of 633 | farah
# Processing Record 63 of 633 | aklavik
# Processing Record 64 of 633 | leningradskiy
# Processing Record 65 of 633 | chokurdakh
# Processing Record 66 of 633 | carmarthen
# Processing Record 67 of 633 | bengkulu
# Processing Record 68 of 633 | puerto ayora
# Processing Record 69 of 633 | dabakala
# Processing Record 70 of 633 | puerto pinasco
# City not found. Skipping...
# Processing Record 71 of 633 | port elizabeth
# Processing Record 72 of 633 | fort wellington
# Processing Record 73 of 633 | karamea
# City not found. Skipping...
# Processing Record 74 of 633 | zhuhai
# Processing Record 75 of 633 | mar del plata
# Processing Record 76 of 633 | bandarbeyla
# Processing Record 77 of 633 | hermanus
# Processing Record 78 of 633 | kayerkan
# Processing Record 79 of 633 | itarema
# Processing Record 80 of 633 | denpasar
# Processing Record 81 of 633 | atuona
# Processing Record 82 of 633 | prince rupert
# Processing Record 83 of 633 | coxquihui
# Processing Record 84 of 633 | mareeba
# Processing Record 85 of 633 | guatire
# Processing Record 86 of 633 | tevaitoa
# Processing Record 87 of 633 | tuatapere
# Processing Record 88 of 633 | maxixe
# Processing Record 89 of 633 | sept-iles
# Processing Record 90 of 633 | louisbourg
# City not found. Skipping...
# Processing Record 91 of 633 | rosario
# Processing Record 92 of 633 | cockburn harbour
# City not found. Skipping...
# Processing Record 93 of 633 | raudeberg
# Processing Record 94 of 633 | kodiak
# Processing Record 95 of 633 | awjilah
# Processing Record 96 of 633 | barrow
# Processing Record 97 of 633 | hasaki
# Processing Record 98 of 633 | saleaula
# City not found. Skipping...
# Processing Record 99 of 633 | olinda
# Processing Record 100 of 633 | port hardy
# Processing Record 101 of 633 | avera
# Processing Record 102 of 633 | clyde river
# Processing Record 103 of 633 | geraldton
# Processing Record 104 of 633 | nemuro
# Processing Record 105 of 633 | klaksvik
# Processing Record 106 of 633 | nouadhibou
# Processing Record 107 of 633 | maceio
# Processing Record 108 of 633 | albany
# Processing Record 109 of 633 | tatarsk
# Processing Record 110 of 633 | touros
# Processing Record 111 of 633 | ilhabela
# Processing Record 112 of 633 | paradwip
# City not found. Skipping...
# Processing Record 113 of 633 | ust-omchug
# Processing Record 114 of 633 | am timan
# Processing Record 115 of 633 | isangel
# Processing Record 116 of 633 | bahia blanca
# Processing Record 117 of 633 | umm lajj
# Processing Record 118 of 633 | chernyshevskiy
# Processing Record 119 of 633 | bambous virieux
# Processing Record 120 of 633 | longyearbyen
# Processing Record 121 of 633 | hualmay
# Processing Record 122 of 633 | ugra
# Processing Record 123 of 633 | bethel
# Processing Record 124 of 633 | georgetown
# Processing Record 125 of 633 | sao filipe
# Processing Record 126 of 633 | ola
# Processing Record 127 of 633 | vardo
# Processing Record 128 of 633 | cabo san lucas
# Processing Record 129 of 633 | new norfolk
# Processing Record 130 of 633 | narsaq
# Processing Record 131 of 633 | gaziantep
# Processing Record 132 of 633 | nikolskoye
# Processing Record 133 of 633 | guane
# Processing Record 134 of 633 | bathsheba
# Processing Record 135 of 633 | chapais
# Processing Record 136 of 633 | cidreira
# Processing Record 137 of 633 | ponta do sol
# Processing Record 138 of 633 | kalabo
# Processing Record 139 of 633 | cap-aux-meules
# Processing Record 140 of 633 | hamilton
# Processing Record 141 of 633 | satitoa
# City not found. Skipping...
# Processing Record 142 of 633 | gornopravdinsk
# Processing Record 143 of 633 | road town
# Processing Record 144 of 633 | pandan
# Processing Record 145 of 633 | bandar-e lengeh
# Processing Record 146 of 633 | kawalu
# Processing Record 147 of 633 | abu zabad
# Processing Record 148 of 633 | walvis bay
# Processing Record 149 of 633 | flinders
# Processing Record 150 of 633 | maldonado
# Processing Record 151 of 633 | severnyy
# Processing Record 152 of 633 | upernavik
# Processing Record 153 of 633 | bima
# Processing Record 154 of 633 | lolua
# City not found. Skipping...
# Processing Record 155 of 633 | margate
# Processing Record 156 of 633 | ust-uda
# Processing Record 157 of 633 | cayambe
# Processing Record 158 of 633 | ribeira grande
# Processing Record 159 of 633 | kysyl-syr
# Processing Record 160 of 633 | inongo
# Processing Record 161 of 633 | abha
# Processing Record 162 of 633 | tumannyy
# City not found. Skipping...
# Processing Record 163 of 633 | blagoyevo
# Processing Record 164 of 633 | sentyabrskiy
# City not found. Skipping...
# Processing Record 165 of 633 | sitka
# Processing Record 166 of 633 | aykhal
# Processing Record 167 of 633 | lebu
# Processing Record 168 of 633 | vangaindrano
# Processing Record 169 of 633 | luderitz
# Processing Record 170 of 633 | bargal
# City not found. Skipping...
# Processing Record 171 of 633 | urengoy
# Processing Record 172 of 633 | komsomolskiy
# Processing Record 173 of 633 | tuktoyaktuk
# Processing Record 174 of 633 | muros
# Processing Record 175 of 633 | laguna
# Processing Record 176 of 633 | katangli
# Processing Record 177 of 633 | sturgeon falls
# Processing Record 178 of 633 | hailar
# Processing Record 179 of 633 | sola
# Processing Record 180 of 633 | sorvag
# City not found. Skipping...
# Processing Record 181 of 633 | wenatchee
# Processing Record 182 of 633 | athens
# Processing Record 183 of 633 | kaitangata
# Processing Record 184 of 633 | east london
# Processing Record 185 of 633 | mys shmidta
# City not found. Skipping...
# Processing Record 186 of 633 | belushya guba
# City not found. Skipping...
# Processing Record 187 of 633 | weligama
# Processing Record 188 of 633 | kavaratti
# Processing Record 189 of 633 | hervey bay
# Processing Record 190 of 633 | vryheid
# Processing Record 191 of 633 | shimoda
# Processing Record 192 of 633 | santa isabel do rio negro
# Processing Record 193 of 633 | katiola
# Processing Record 194 of 633 | rovaniemi
# Processing Record 195 of 633 | hilo
# Processing Record 196 of 633 | morristown
# Processing Record 197 of 633 | husavik
# Processing Record 198 of 633 | talnakh
# Processing Record 199 of 633 | kruisfontein
# Processing Record 200 of 633 | amderma
# City not found. Skipping...
# Processing Record 201 of 633 | saint-augustin
# Processing Record 202 of 633 | leh
# Processing Record 203 of 633 | raga
# Processing Record 204 of 633 | erdenet
# Processing Record 205 of 633 | muroto
# Processing Record 206 of 633 | lompoc
# Processing Record 207 of 633 | royan
# Processing Record 208 of 633 | pudozh
# Processing Record 209 of 633 | khandyga
# Processing Record 210 of 633 | pevek
# Processing Record 211 of 633 | marevo
# Processing Record 212 of 633 | daru
# Processing Record 213 of 633 | edd
# Processing Record 214 of 633 | tessalit
# Processing Record 215 of 633 | saint-philippe
# Processing Record 216 of 633 | pisco
# Processing Record 217 of 633 | thompson
# Processing Record 218 of 633 | faanui
# Processing Record 219 of 633 | umzimvubu
# City not found. Skipping...
# Processing Record 220 of 633 | san felipe
# Processing Record 221 of 633 | kuche
# City not found. Skipping...
# Processing Record 222 of 633 | karratha
# Processing Record 223 of 633 | tautira
# Processing Record 224 of 633 | katsuura
# Processing Record 225 of 633 | huimanguillo
# Processing Record 226 of 633 | zhitikara
# City not found. Skipping...
# Processing Record 227 of 633 | alofi
# Processing Record 228 of 633 | palmer
# Processing Record 229 of 633 | harper
# Processing Record 230 of 633 | chikoy
# City not found. Skipping...
# Processing Record 231 of 633 | nizhneyansk
# City not found. Skipping...
# Processing Record 232 of 633 | mahebourg
# Processing Record 233 of 633 | caravelas
# Processing Record 234 of 633 | chapleau
# Processing Record 235 of 633 | lata
# Processing Record 236 of 633 | banda aceh
# Processing Record 237 of 633 | alugan
# Processing Record 238 of 633 | guerrero negro
# Processing Record 239 of 633 | naron
# Processing Record 240 of 633 | dunedin
# Processing Record 241 of 633 | key west
# Processing Record 242 of 633 | kozhevnikovo
# Processing Record 243 of 633 | ruwi
# Processing Record 244 of 633 | bidduang
# City not found. Skipping...
# Processing Record 245 of 633 | janow lubelski
# Processing Record 246 of 633 | frontera
# Processing Record 247 of 633 | chuy
# Processing Record 248 of 633 | grand river south east
# City not found. Skipping...
# Processing Record 249 of 633 | jalu
# Processing Record 250 of 633 | victoria
# Processing Record 251 of 633 | belaya gora
# Processing Record 252 of 633 | trebisacce
# Processing Record 253 of 633 | taoudenni
# Processing Record 254 of 633 | gualaquiza
# Processing Record 255 of 633 | kjollefjord
# Processing Record 256 of 633 | samusu
# City not found. Skipping...
# Processing Record 257 of 633 | yanan
# City not found. Skipping...
# Processing Record 258 of 633 | nuuk
# Processing Record 259 of 633 | beringovskiy
# Processing Record 260 of 633 | iralaya
# Processing Record 261 of 633 | wewak
# Processing Record 262 of 633 | monopoli
# Processing Record 263 of 633 | nabire
# Processing Record 264 of 633 | rawannawi
# City not found. Skipping...
# Processing Record 265 of 633 | dunyapur
# Processing Record 266 of 633 | mogadishu
# Processing Record 267 of 633 | verkhnyaya inta
# Processing Record 268 of 633 | taburi
# City not found. Skipping...
# Processing Record 269 of 633 | zhigansk
# Processing Record 270 of 633 | arman
# Processing Record 271 of 633 | cedar city
# Processing Record 272 of 633 | paracuru
# Processing Record 273 of 633 | frontignan
# Processing Record 274 of 633 | helong
# Processing Record 275 of 633 | iglesias
# Processing Record 276 of 633 | morondava
# Processing Record 277 of 633 | san rafael del sur
# Processing Record 278 of 633 | vila velha
# Processing Record 279 of 633 | avila
# Processing Record 280 of 633 | vaitupu
# City not found. Skipping...
# Processing Record 281 of 633 | esperance
# Processing Record 282 of 633 | correia pinto
# Processing Record 283 of 633 | fuchu
# Processing Record 284 of 633 | ilulissat
# Processing Record 285 of 633 | longonjo
# Processing Record 286 of 633 | iranshahr
# Processing Record 287 of 633 | one hundred mile house
# City not found. Skipping...
# Processing Record 288 of 633 | gorontalo
# Processing Record 289 of 633 | cleethorpes
# Processing Record 290 of 633 | saint george
# Processing Record 291 of 633 | kudahuvadhoo
# Processing Record 292 of 633 | turukhansk
# Processing Record 293 of 633 | amga
# Processing Record 294 of 633 | sibolga
# Processing Record 295 of 633 | comrie
# Processing Record 296 of 633 | kampong thum
# Processing Record 297 of 633 | yangambi
# Processing Record 298 of 633 | cherdyn
# Processing Record 299 of 633 | kenai
# Processing Record 300 of 633 | prince george
# Processing Record 301 of 633 | norman wells
# Processing Record 302 of 633 | elizabeth city
# Processing Record 303 of 633 | abu samrah
# Processing Record 304 of 633 | shelburne
# Processing Record 305 of 633 | oranjemund
# Processing Record 306 of 633 | broome
# Processing Record 307 of 633 | jumla
# Processing Record 308 of 633 | sur
# Processing Record 309 of 633 | mount isa
# Processing Record 310 of 633 | harbour breton
# Processing Record 311 of 633 | taboao da serra
# Processing Record 312 of 633 | russell
# Processing Record 313 of 633 | lorengau
# Processing Record 314 of 633 | lensk
# Processing Record 315 of 633 | mumford
# Processing Record 316 of 633 | puerto leguizamo
# Processing Record 317 of 633 | helena
# Processing Record 318 of 633 | nome
# Processing Record 319 of 633 | goderich
# Processing Record 320 of 633 | tigil
# Processing Record 321 of 633 | saint anthony
# Processing Record 322 of 633 | fort nelson
# Processing Record 323 of 633 | cherskiy
# Processing Record 324 of 633 | jabinyanah
# Processing Record 325 of 633 | portland
# Processing Record 326 of 633 | ewa beach
# Processing Record 327 of 633 | santa rosa
# Processing Record 328 of 633 | bahir dar
# Processing Record 329 of 633 | oum hadjer
# Processing Record 330 of 633 | poum
# Processing Record 331 of 633 | eureka
# Processing Record 332 of 633 | zabol
# Processing Record 333 of 633 | sisimiut
# Processing Record 334 of 633 | strezhevoy
# Processing Record 335 of 633 | henties bay
# Processing Record 336 of 633 | aquiraz
# Processing Record 337 of 633 | inhambane
# Processing Record 338 of 633 | torbay
# Processing Record 339 of 633 | diamantino
# Processing Record 340 of 633 | sindor
# Processing Record 341 of 633 | khonuu
# City not found. Skipping...
# Processing Record 342 of 633 | telenesti
# Processing Record 343 of 633 | melun
# Processing Record 344 of 633 | mangan
# Processing Record 345 of 633 | karatuzskoye
# Processing Record 346 of 633 | kodinsk
# Processing Record 347 of 633 | sioux lookout
# Processing Record 348 of 633 | quatre cocos
# Processing Record 349 of 633 | bintulu
# Processing Record 350 of 633 | tashtagol
# Processing Record 351 of 633 | salalah
# Processing Record 352 of 633 | lugovoy
# Processing Record 353 of 633 | lagoa
# Processing Record 354 of 633 | sobolevo
# Processing Record 355 of 633 | loandjili
# Processing Record 356 of 633 | cayenne
# Processing Record 357 of 633 | ust-barguzin
# Processing Record 358 of 633 | long
# Processing Record 359 of 633 | sangar
# Processing Record 360 of 633 | kungurtug
# Processing Record 361 of 633 | iqaluit
# Processing Record 362 of 633 | freeport
# Processing Record 363 of 633 | barcelos
# Processing Record 364 of 633 | verkh-usugli
# Processing Record 365 of 633 | wuwei
# Processing Record 366 of 633 | batangafo
# Processing Record 367 of 633 | mega
# Processing Record 368 of 633 | slave lake
# Processing Record 369 of 633 | codrington
# Processing Record 370 of 633 | alihe
# Processing Record 371 of 633 | mayor pablo lagerenza
# Processing Record 372 of 633 | navolato
# Processing Record 373 of 633 | haines junction
# Processing Record 374 of 633 | souillac
# Processing Record 375 of 633 | brigantine
# Processing Record 376 of 633 | kuryk
# Processing Record 377 of 633 | bay roberts
# Processing Record 378 of 633 | tsihombe
# City not found. Skipping...
# Processing Record 379 of 633 | namibe
# Processing Record 380 of 633 | dubbo
# Processing Record 381 of 633 | chara
# Processing Record 382 of 633 | salekhard
# Processing Record 383 of 633 | general pico
# Processing Record 384 of 633 | natal
# Processing Record 385 of 633 | bubaque
# Processing Record 386 of 633 | muisne
# Processing Record 387 of 633 | abaza
# Processing Record 388 of 633 | lelydorp
# Processing Record 389 of 633 | trelew
# Processing Record 390 of 633 | paola
# Processing Record 391 of 633 | necochea
# Processing Record 392 of 633 | george
# Processing Record 393 of 633 | vyazemskiy
# Processing Record 394 of 633 | timizart
# Processing Record 395 of 633 | marrakesh
# Processing Record 396 of 633 | redmond
# Processing Record 397 of 633 | niksar
# Processing Record 398 of 633 | kazalinsk
# City not found. Skipping...
# Processing Record 399 of 633 | hofn
# Processing Record 400 of 633 | urucara
# Processing Record 401 of 633 | lisakovsk
# Processing Record 402 of 633 | wana
# Processing Record 403 of 633 | laguna de perlas
# Processing Record 404 of 633 | sterling
# Processing Record 405 of 633 | hingorja
# Processing Record 406 of 633 | sierpc
# Processing Record 407 of 633 | utiroa
# City not found. Skipping...
# Processing Record 408 of 633 | praya
# Processing Record 409 of 633 | port-gentil
# Processing Record 410 of 633 | maba
# Processing Record 411 of 633 | ambilobe
# Processing Record 412 of 633 | sjovegan
# Processing Record 413 of 633 | kota belud
# Processing Record 414 of 633 | san roque
# Processing Record 415 of 633 | roros
# Processing Record 416 of 633 | chipinge
# Processing Record 417 of 633 | umm bab
# Processing Record 418 of 633 | praia da vitoria
# Processing Record 419 of 633 | maki
# Processing Record 420 of 633 | isabela
# Processing Record 421 of 633 | taber
# Processing Record 422 of 633 | saint-pierre
# Processing Record 423 of 633 | cap malheureux
# Processing Record 424 of 633 | phek
# Processing Record 425 of 633 | marawi
# Processing Record 426 of 633 | civitavecchia
# Processing Record 427 of 633 | masvingo
# Processing Record 428 of 633 | cambrils
# Processing Record 429 of 633 | batagay
# Processing Record 430 of 633 | gizo
# Processing Record 431 of 633 | katsiveli
# City not found. Skipping...
# Processing Record 432 of 633 | marsaxlokk
# Processing Record 433 of 633 | oron
# Processing Record 434 of 633 | marcona
# City not found. Skipping...
# Processing Record 435 of 633 | kahului
# Processing Record 436 of 633 | rock sound
# Processing Record 437 of 633 | galiwinku
# City not found. Skipping...
# Processing Record 438 of 633 | camacha
# Processing Record 439 of 633 | sao joao da barra
# Processing Record 440 of 633 | campo maior
# Processing Record 441 of 633 | mayo
# Processing Record 442 of 633 | ust-nera
# Processing Record 443 of 633 | chitral
# Processing Record 444 of 633 | yermish
# Processing Record 445 of 633 | morant bay
# Processing Record 446 of 633 | mangrol
# Processing Record 447 of 633 | takoradi
# Processing Record 448 of 633 | kanigiri
# Processing Record 449 of 633 | dubuque
# Processing Record 450 of 633 | san andres
# Processing Record 451 of 633 | conakry
# Processing Record 452 of 633 | tura
# Processing Record 453 of 633 | skali
# City not found. Skipping...
# Processing Record 454 of 633 | vanimo
# Processing Record 455 of 633 | borovskoy
# Processing Record 456 of 633 | ambon
# Processing Record 457 of 633 | san ramon
# Processing Record 458 of 633 | los llanos de aridane
# Processing Record 459 of 633 | clonakilty
# Processing Record 460 of 633 | high level
# Processing Record 461 of 633 | general roca
# Processing Record 462 of 633 | barcelona
# Processing Record 463 of 633 | fairbanks
# Processing Record 464 of 633 | santa fe
# Processing Record 465 of 633 | kovdor
# Processing Record 466 of 633 | broken hill
# Processing Record 467 of 633 | chenzhou
# Processing Record 468 of 633 | kattivakkam
# Processing Record 469 of 633 | zelenoborskiy
# Processing Record 470 of 633 | diffa
# Processing Record 471 of 633 | garissa
# Processing Record 472 of 633 | kulhudhuffushi
# Processing Record 473 of 633 | sa kaeo
# Processing Record 474 of 633 | umm kaddadah
# Processing Record 475 of 633 | kolondieba
# Processing Record 476 of 633 | shakhtinsk
# Processing Record 477 of 633 | yzeure
# Processing Record 478 of 633 | eyl
# Processing Record 479 of 633 | eugene
# Processing Record 480 of 633 | boende
# Processing Record 481 of 633 | sao francisco de paula
# Processing Record 482 of 633 | algiers
# Processing Record 483 of 633 | cabra
# Processing Record 484 of 633 | darhan
# Processing Record 485 of 633 | balashov
# Processing Record 486 of 633 | dolinsk
# Processing Record 487 of 633 | zachagansk
# City not found. Skipping...
# Processing Record 488 of 633 | suntar
# Processing Record 489 of 633 | grand gaube
# Processing Record 490 of 633 | dudinka
# Processing Record 491 of 633 | lamu
# Processing Record 492 of 633 | kavieng
# Processing Record 493 of 633 | mansa
# Processing Record 494 of 633 | hambantota
# Processing Record 495 of 633 | northam
# Processing Record 496 of 633 | dingle
# Processing Record 497 of 633 | chicama
# Processing Record 498 of 633 | lazaro cardenas
# Processing Record 499 of 633 | honningsvag
# Processing Record 500 of 633 | poronaysk
# Processing Record 501 of 633 | mason city
# Processing Record 502 of 633 | the valley
# Processing Record 503 of 633 | pacific grove
# Processing Record 504 of 633 | tari
# Processing Record 505 of 633 | salta
# Processing Record 506 of 633 | waingapu
# Processing Record 507 of 633 | sataua
# City not found. Skipping...
# Processing Record 508 of 633 | gimli
# Processing Record 509 of 633 | bowen
# Processing Record 510 of 633 | gelemso
# Processing Record 511 of 633 | kijang
# Processing Record 512 of 633 | xiongshi
# City not found. Skipping...
# Processing Record 513 of 633 | kazachinskoye
# Processing Record 514 of 633 | srednekolymsk
# Processing Record 515 of 633 | bethanien
# Processing Record 516 of 633 | burica
# City not found. Skipping...
# Processing Record 517 of 633 | atar
# Processing Record 518 of 633 | coquimbo
# Processing Record 519 of 633 | norrkoping
# Processing Record 520 of 633 | perth
# Processing Record 521 of 633 | bousso
# Processing Record 522 of 633 | venado tuerto
# Processing Record 523 of 633 | paamiut
# Processing Record 524 of 633 | doka
# Processing Record 525 of 633 | cristalina
# Processing Record 526 of 633 | cabedelo
# Processing Record 527 of 633 | kanchanaburi
# Processing Record 528 of 633 | el faiyum
# City not found. Skipping...
# Processing Record 529 of 633 | santander jimenez
# Processing Record 530 of 633 | valentin gomez farias
# Processing Record 531 of 633 | zlitan
# Processing Record 532 of 633 | dombarovskiy
# Processing Record 533 of 633 | kirkwall
# Processing Record 534 of 633 | safwah
# City not found. Skipping...
# Processing Record 535 of 633 | rungata
# City not found. Skipping...
# Processing Record 536 of 633 | constitucion
# Processing Record 537 of 633 | cozumel
# Processing Record 538 of 633 | liwan
# Processing Record 539 of 633 | tateyama
# Processing Record 540 of 633 | emerald
# Processing Record 541 of 633 | juneau
# Processing Record 542 of 633 | vila franca do campo
# Processing Record 543 of 633 | porto walter
# Processing Record 544 of 633 | pasto
# Processing Record 545 of 633 | killam
# Processing Record 546 of 633 | ouadda
# Processing Record 547 of 633 | korla
# Processing Record 548 of 633 | baruun-urt
# Processing Record 549 of 633 | hamadan
# Processing Record 550 of 633 | viet tri
# Processing Record 551 of 633 | ankang
# Processing Record 552 of 633 | ponta delgada
# Processing Record 553 of 633 | moberly
# Processing Record 554 of 633 | ketchikan
# Processing Record 555 of 633 | trairi
# Processing Record 556 of 633 | merrill
# Processing Record 557 of 633 | opuwo
# Processing Record 558 of 633 | airai
# Processing Record 559 of 633 | paragominas
# Processing Record 560 of 633 | kuva
# City not found. Skipping...
# Processing Record 561 of 633 | vostok
# Processing Record 562 of 633 | ajdabiya
# Processing Record 563 of 633 | naile
# City not found. Skipping...
# Processing Record 564 of 633 | xuanzhou
# Processing Record 565 of 633 | yarmouth
# Processing Record 566 of 633 | dumas
# Processing Record 567 of 633 | uige
# Processing Record 568 of 633 | katastarion
# Processing Record 569 of 633 | gold coast
# Processing Record 570 of 633 | ahipara
# Processing Record 571 of 633 | chase
# Processing Record 572 of 633 | fairview
# Processing Record 573 of 633 | las cruces
# Processing Record 574 of 633 | merida
# Processing Record 575 of 633 | bonfim
# Processing Record 576 of 633 | farafangana
# Processing Record 577 of 633 | moose factory
# Processing Record 578 of 633 | zonguldak
# Processing Record 579 of 633 | takapau
# Processing Record 580 of 633 | mnogovershinnyy
# Processing Record 581 of 633 | san quintin
# Processing Record 582 of 633 | mandera
# Processing Record 583 of 633 | belmonte
# Processing Record 584 of 633 | riyadh
# Processing Record 585 of 633 | bolshaya sosnova
# Processing Record 586 of 633 | jibuti
# Processing Record 587 of 633 | betioky
# Processing Record 588 of 633 | dryden
# Processing Record 589 of 633 | tabou
# Processing Record 590 of 633 | calama
# Processing Record 591 of 633 | novichikha
# Processing Record 592 of 633 | takhtamygda
# Processing Record 593 of 633 | genhe
# Processing Record 594 of 633 | alenquer
# Processing Record 595 of 633 | aquidauana
# Processing Record 596 of 633 | hanzhong
# Processing Record 597 of 633 | tarakan
# Processing Record 598 of 633 | patrocinio
# Processing Record 599 of 633 | le port
# Processing Record 600 of 633 | chagda
# City not found. Skipping...
# Processing Record 601 of 633 | severnyy-kospashskiy
# Processing Record 602 of 633 | alsonemedi
# Processing Record 603 of 633 | casablanca
# Processing Record 604 of 633 | el angel
# Processing Record 605 of 633 | grand-lahou
# Processing Record 606 of 633 | nioro
# Processing Record 607 of 633 | bolungarvik
# City not found. Skipping...
# Processing Record 608 of 633 | westport
# Processing Record 609 of 633 | nogent-sur-oise
# Processing Record 610 of 633 | makueni
# Processing Record 611 of 633 | cheuskiny
# City not found. Skipping...
# Processing Record 612 of 633 | rognan
# Processing Record 613 of 633 | artyk
# City not found. Skipping...
# Processing Record 614 of 633 | ferrol
# Processing Record 615 of 633 | shitanjing
# Processing Record 616 of 633 | aflu
# City not found. Skipping...
# Processing Record 617 of 633 | russkaya polyana
# Processing Record 618 of 633 | florence
# Processing Record 619 of 633 | smithers
# Processing Record 620 of 633 | saint-francois
# Processing Record 621 of 633 | talaya
# Processing Record 622 of 633 | kaeo
# Processing Record 623 of 633 | sagua de tanamo
# Processing Record 624 of 633 | merauke
# Processing Record 625 of 633 | fairlie
# Processing Record 626 of 633 | grand centre
# City not found. Skipping...
# Processing Record 627 of 633 | nyurba
# Processing Record 628 of 633 | santa luzia
# Processing Record 629 of 633 | yar-sale
# Processing Record 630 of 633 | peniche
# Processing Record 631 of 633 | emba
# Processing Record 632 of 633 | tiverton
# Processing Record 633 of 633 | hammerfest

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv(output_data_file)
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           camacha  77.4840 -69.3632    -23.67        67          98
# 1           fairlie -33.5906  26.8910     21.67        73          75
# 2       port-gentil -29.1253 -56.5531     23.69        88           0
# 3              chuy  34.7304 -86.5861      2.22        69           1
# 4          sjovegan  42.0970 -79.2353     -6.67        79          90
# ..              ...      ...      ...       ...       ...         ...
# 571       tashtagol  66.8333  70.8333    -38.09        81          16
# 572            phek  39.3558  -9.3811     13.89        80          80
# 573        chapleau  48.8264  58.1442     -5.44        95          99
# 574      santa rosa  50.9000  -3.4833      9.44        96          71
# 575  ribeira grande  70.6634  23.6821     -6.00        73          40
#
#      Wind Speed Country        Date
# 0          2.19      GL  1611989468
# 1          1.34      ZA  1611989244
# 2          3.67      BR  1611989711
# 3          1.96      US  1611989711
# 4          2.06      US  1611989170
# ..          ...     ...         ...
# 571        3.07      RU  1611989760
# 572        3.58      PT  1611989760
# 573        2.59      KZ  1611989469
# 574        1.83      GB  1611989760
# 575        5.14      NO  1611989760
#
# [576 rows x 9 columns]

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  576.000000  576.000000  576.000000  576.000000  576.000000  576.000000
# mean    22.406116   13.560301    8.350538   72.805556   52.532986    3.651302
# std     32.743488   88.545838   19.684677   20.483555   41.272612    2.457599
# min    -54.800000 -179.166700  -44.830000    9.000000    0.000000    0.130000
# 25%     -2.935275  -61.886975   -3.890000   65.000000    1.000000    1.830000
# 50%     27.746800   16.859800   15.065000   78.500000   64.500000    3.090000
# 75%     50.125100   87.792500   24.000000   87.250000   97.250000    5.140000
# max     78.218600  179.316700   38.000000  100.000000  100.000000   13.380000
#
#                Date
# count  5.760000e+02
# mean   1.611990e+09
# std    1.460354e+02
# min    1.611989e+09
# 25%    1.611989e+09
# 50%    1.611990e+09
# 75%    1.611990e+09
# max    1.611990e+09

# %%
weather_data.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# weather_data_humidity = weather_data.loc("Humidity">'100')
weather_data_humidity = weather_data[(weather_data["Humidity"]> 100)].index
weather_data_humidity
# Out:
# Int64Index([], dtype='int64')

# %%
less_humid_cities = weather_data[(weather_data["Humidity"] <= 100)]
less_humid_cities
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           camacha  77.4840 -69.3632    -23.67        67          98
# 1           fairlie -33.5906  26.8910     21.67        73          75
# 2       port-gentil -29.1253 -56.5531     23.69        88           0
# 3              chuy  34.7304 -86.5861      2.22        69           1
# 4          sjovegan  42.0970 -79.2353     -6.67        79          90
# ..              ...      ...      ...       ...       ...         ...
# 571       tashtagol  66.8333  70.8333    -38.09        81          16
# 572            phek  39.3558  -9.3811     13.89        80          80
# 573        chapleau  48.8264  58.1442     -5.44        95          99
# 574      santa rosa  50.9000  -3.4833      9.44        96          71
# 575  ribeira grande  70.6634  23.6821     -6.00        73          40
#
#      Wind Speed Country        Date
# 0          2.19      GL  1611989468
# 1          1.34      ZA  1611989244
# 2          3.67      BR  1611989711
# 3          1.96      US  1611989711
# 4          2.06      US  1611989170
# ..          ...     ...         ...
# 571        3.07      RU  1611989760
# 572        3.58      PT  1611989760
# 573        2.59      KZ  1611989469
# 574        1.83      GB  1611989760
# 575        5.14      NO  1611989760
#
# [576 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
weather_data_humid_cities_index = weather_data[(weather_data["Humidity"]> 100)].index
weather_data_humid_cities_index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data.drop(weather_data_humidity, inplace=False)
clean_city_data
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           camacha  77.4840 -69.3632    -23.67        67          98
# 1           fairlie -33.5906  26.8910     21.67        73          75
# 2       port-gentil -29.1253 -56.5531     23.69        88           0
# 3              chuy  34.7304 -86.5861      2.22        69           1
# 4          sjovegan  42.0970 -79.2353     -6.67        79          90
# ..              ...      ...      ...       ...       ...         ...
# 571       tashtagol  66.8333  70.8333    -38.09        81          16
# 572            phek  39.3558  -9.3811     13.89        80          80
# 573        chapleau  48.8264  58.1442     -5.44        95          99
# 574      santa rosa  50.9000  -3.4833      9.44        96          71
# 575  ribeira grande  70.6634  23.6821     -6.00        73          40
#
#      Wind Speed Country        Date
# 0          2.19      GL  1611989468
# 1          1.34      ZA  1611989244
# 2          3.67      BR  1611989711
# 3          1.96      US  1611989711
# 4          2.06      US  1611989170
# ..          ...     ...         ...
# 571        3.07      RU  1611989760
# 572        3.58      PT  1611989760
# 573        2.59      KZ  1611989469
# 574        1.83      GB  1611989760
# 575        5.14      NO  1611989760
#
# [576 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = clean_city_data["Lat"]
max_temp = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]
# print(latitude)


plt.scatter(latitude, max_temp, edgecolor="black", linewidths=1, marker="o", alpha = 0.5, label = "Cities")
plt.title("City Latitude vs Max Temperature (%s)"%time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the Latitude vs. Temperature Plot
plt.savefig("output_data/Lat_vs_Max_Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(latitude, humidity, edgecolor="black", linewidths=1, marker="o", alpha = 0.5, label = "Cities")
plt.title("City Latitude vs Humidity (%s)"%time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#Save the Latitude vs. Temperature Plot
plt.savefig("output_data/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(latitude, cloudiness, edgecolor="black", linewidths=1, marker="o", alpha = 0.5, label = "Cities")
plt.title("City Latitude vs Cloudiness (%s)"%time.strftime("%x"))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#Save the Latitude vs. Temperature Plot
plt.savefig("output_data/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(latitude, wind_speed, edgecolor="black", linewidths=1, marker="o", alpha = 0.5, label = "Cities")
plt.title("City Latitude vs Wind Speed (%s)"%time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the Latitude vs. Temperature Plot
plt.savefig("output_data/City Latitude vs Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
#Linear Regression plot function
def linear_regression_plot(x_values, y_values, title,text_coordinates):
    (slope,intercept,rvalue,pvalue,stderr)=linregress(x_values,y_values)
    regress_values = x_values*slope+intercept
    line_eq = "y= "+str(round(slope,2))+"x + " +str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize =20, color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r value is: {rvalue**2}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_hemisphere = weather_data.loc[(weather_data["Lat"]>=0)]
x_values = north_hemisphere["Lat"]
y_values = north_hemisphere["Max Temp"]
linear_regression_plot(x_values,y_values,'Max Temp vs Latitude (North Hem)', (0,10))
# Out:
# The r value is: 0.7485291064554448

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_hemisphere = weather_data.loc[(weather_data["Lat"]<=0)]
x_values = south_hemisphere["Lat"]
y_values = south_hemisphere["Max Temp"]
linear_regression_plot(x_values,y_values,'Max Temp vs Latitude (South Hem)', (-30,15))
# Out:
# The r value is: 0.21508072194155078

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_hemisphere = weather_data.loc[(weather_data["Lat"]>=0)]
x_values = north_hemisphere["Lat"]
y_values = north_hemisphere["Humidity"]
linear_regression_plot(x_values,y_values,'Humidity vs Latitude (North Hem)', (10,40))
# Out:
# The r value is: 0.15007762839291156

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_hemisphere = weather_data.loc[(weather_data["Lat"]<=0)]
x_values = south_hemisphere["Lat"]
y_values = south_hemisphere["Humidity"]
linear_regression_plot(x_values,y_values,'Humidity vs Latitude (South Hem)', (-40,50))
# Out:
# The r value is: 0.04541382425309718

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_hemisphere = weather_data.loc[(weather_data["Lat"]>=0)]
x_values = north_hemisphere["Lat"]
y_values = north_hemisphere["Cloudiness"]
linear_regression_plot(x_values,y_values,'Cloudiness % vs Latitude (North Hem)', (10,40))
# Out:
# The r value is: 0.07867108988433645

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_hemisphere = weather_data.loc[(weather_data["Lat"]<=0)]
x_values = south_hemisphere["Lat"]
y_values = south_hemisphere["Cloudiness"]
linear_regression_plot(x_values,y_values,'Cloudiness % vs Latitude (South Hem)', (-40,50))
# Out:
# The r value is: 0.10805784485420122

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_hemisphere = weather_data.loc[(weather_data["Lat"]>=0)]
x_values = north_hemisphere["Lat"]
y_values = north_hemisphere["Wind Speed"]
linear_regression_plot(x_values,y_values,'Wind Speed (mph) vs Latitude (North Hem)', (10,6))
# Out:
# The r value is: 4.5664648925642284e-07

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_hemisphere = weather_data.loc[(weather_data["Lat"]<=0)]
x_values = south_hemisphere["Lat"]
y_values = south_hemisphere["Wind Speed"]
linear_regression_plot(x_values,y_values,'Wind Speed (mph) vs Latitude (South Hem)', (-50,5))
# Out:
# The r value is: 0.006735359904302151
